# %% [markdown]
# #Container types intro
# Container/Reference types
# -list

# %%
a = [1, 2, 3]
b = a #reference assignment
a.append(5)
print(a)
print(b)
# Out:
# [1, 2, 3, 5]
# [1, 2, 3, 5]

# %%
a = [
   ["apple", "name", "terror"],
   ["surname", "sick", "exam"],
   ["inter", "yahoo", "who"]

]
print(a[0:12])
# Out:
# [['apple', 'name', 'terror'], ['surname', 'sick', 'exam'], ['inter', 'yahoo', 'who']]
